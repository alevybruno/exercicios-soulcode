# %%
# !pip install mysql-connector-python
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.4/34.4 MB 16.5 MB/s eta 0:00:00
# ...

# %%
import mysql.connector
import pandas as pd

# %%
host = "SEU_HOST"
user = "SEU_USUARIO"
password = "SUA_SENHA"
database = "SEU_BANCO"

# %%
# !curl ipecho.net/plain
# Out:
# 35.236.149.186

# %%
connection = mysql.connector.connect(
    host=host,
    user=user,
    password=password,
    database=database,
)
cursor = connection.cursor()
query = 'show tables;'
cursor.execute(query)
result = cursor.fetchall()
tabelas = pd.DataFrame(result,columns=cursor.column_names)
display(tabelas)
cursor.close()
connection.close()
# Out:
#      Tables_in_loja
# 0         Categoria
# 1           Cliente
# 2        ItemPedido
# 3            Pedido
# 4           Produto
# 5  ProdutoCategoria

# %%
connection = mysql.connector.connect(
    host=host,
    user=user,
    password=password,
    database=database,
)
cursor = connection.cursor()
query = 'SELECT * FROM Categoria'
cursor.execute(query)
result = cursor.fetchall()
categoria = pd.DataFrame(result,columns=cursor.column_names)
display(categoria)
cursor.close()
connection.close()

from google.colab import auth
auth.authenticate_user()

project_id = "projeto-alevy"
# !gcloud config set project {project_id}

from google.cloud import storage

client = storage.Client()

bucket_name = "loja-alevy"
bucket = client.bucket(bucket_name)

categoria.to_csv("loja_categoria.csv", index=False)

destination_blob_name = "tabelas/loja_categoria.csv"
source_file_name = "loja_categoria.csv"

blob = bucket.blob(destination_blob_name)
blob.upload_from_filename(source_file_name)
# Out:
#    id_categoria   nome
# 0             1  Comer
# 1             2  Beber
# Updated property [core/project].

# %%
connection = mysql.connector.connect(
    host=host,
    user=user,
    password=password,
    database=database,
)
cursor = connection.cursor()
query = 'SELECT * FROM Cliente'
cursor.execute(query)
result = cursor.fetchall()
cliente = pd.DataFrame(result,columns=cursor.column_names)
display(cliente)
cursor.close()
connection.close()

from google.colab import auth
auth.authenticate_user()

project_id = "projeto-alevy"
# !gcloud config set project {project_id}

from google.cloud import storage

client = storage.Client()

bucket_name = "loja-alevy"
bucket = client.bucket(bucket_name)

cliente.to_csv("loja_cliente.csv", index=False)

destination_blob_name = "tabelas/loja_cliente.csv"
source_file_name = "loja_cliente.csv"

blob = bucket.blob(destination_blob_name)
blob.upload_from_filename(source_file_name)
# Out:
#     id_cliente         nome endereco
# 0            1      Douglas       SP
# 1            2      Daniela       SP
# 2            3        Ester       MG
# 3            4        Maria       BA
# 4            5      Douglas       PE
# 5            6     Raimundo       CE
# 6            7     Jucimara       GO
# 7            8      Marlene       AC
# 8            9      Douglas       MA
# 9           10      Daniela       PI
# 10          11        Pedro       PB
# 11          12      Joaquim       RS
# 12          13        Julio       TO
# 13          14        Carla       DF
# 14          15       Bianca       PA
# 15          16       Sandra       SP
# 16          17        Celso       SP
# 17          18      Silvana       BA
# 18          19  Prof Raquel       BA
# 19          20        Pedro       SP
# 20          21        Erick       BA
# 21          22       Denise       DF
# 22          23        Diana       SP
# 23          24       Dagmar       DF
# ...

# %%
connection = mysql.connector.connect(
    host=host,
    user=user,
    password=password,
    database=database,
)
cursor = connection.cursor()
query = 'SELECT * FROM ItemPedido'
cursor.execute(query)
result = cursor.fetchall()
itempedido = pd.DataFrame(result,columns=cursor.column_names)
display(itempedido)
cursor.close()
connection.close()

from google.colab import auth
auth.authenticate_user()

project_id = "projeto-alevy"
# !gcloud config set project {project_id}

from google.cloud import storage

client = storage.Client()

bucket_name = "loja-alevy"
bucket = client.bucket(bucket_name)

itempedido.to_csv("loja_itempedido.csv", index=False)

destination_blob_name = "tabelas/loja_itempedido.csv"
source_file_name = "loja_itempedido.csv"

blob = bucket.blob(destination_blob_name)
blob.upload_from_filename(source_file_name)
# Out:
#     id_item  id_pedido  id_produto  quantidade
# 0         1          1           1           2
# 1         2          2           2           5
# 2         3          3           3           7
# 3         4          4           5          10
# 4         5          5           5          11
# 5         6          6           4          30
# 6         7          7           4          32
# 7         8          8           4          44
# 8         9          9           5          13
# 9        10         10           4          33
# 10       11         11           5          34
# 11       12         12           4          32
# 12       13         13           2          33
# 13       14         14           2          34
# 14       15         15           4          27
# 15       16         16           2          18
# 16       17         17           5          17
# 17       18         18           2          33
# 18       19         19           1          50
# ...

# %%
connection = mysql.connector.connect(
    host=host,
    user=user,
    password=password,
    database=database,
)
cursor = connection.cursor()
query = 'SELECT * FROM Pedido'
cursor.execute(query)
result = cursor.fetchall()
pedido = pd.DataFrame(result,columns=cursor.column_names)
display(pedido)
cursor.close()
connection.close()

from google.colab import auth
auth.authenticate_user()

project_id = "projeto-alevy"
# !gcloud config set project {project_id}

from google.cloud import storage

client = storage.Client()

bucket_name = "loja-alevy"
bucket = client.bucket(bucket_name)

pedido.to_csv("loja_pedido.csv", index=False)

destination_blob_name = "tabelas/loja_pedido.csv"
source_file_name = "loja_pedido.csv"

blob = bucket.blob(destination_blob_name)
blob.upload_from_filename(source_file_name)
# Out:
#     id_pedido  id_cliente descricao
# 0           1           1    Caneca
# 1           2           1     Garfo
# 2           3           2      Faca
# 3           4           5      Copo
# 4           5          19      Copo
# 5           6          19    Colher
# 6           7          15    Colher
# 7           8           8    Colher
# 8           9           2      Copo
# 9          10          19    Colher
# 10         11           6      Copo
# 11         12          11    Colher
# 12         13          10     Garfo
# 13         14           4     Garfo
# 14         15           3    Colher
# 15         16           3     Garfo
# 16         17           2      Copo
# 17         18          17     Garfo
# 18         19          14    Caneca
# 19         20          13    Caneca
# Updated property [core/project].

# %%
connection = mysql.connector.connect(
    host=host,
    user=user,
    password=password,
    database=database,
)
cursor = connection.cursor()
query = 'SELECT * FROM Produto'
cursor.execute(query)
result = cursor.fetchall()
produto = pd.DataFrame(result,columns=cursor.column_names)
display(produto)
cursor.close()
connection.close()

from google.colab import auth
auth.authenticate_user()

project_id = "projeto-alevy"
# !gcloud config set project {project_id}

from google.cloud import storage

client = storage.Client()

bucket_name = "loja-alevy"
bucket = client.bucket(bucket_name)

produto.to_csv("loja_produto.csv", index=False)

destination_blob_name = "tabelas/loja_produto.csv"
source_file_name = "loja_produto.csv"

blob = bucket.blob(destination_blob_name)
blob.upload_from_filename(source_file_name)
# Out:
#    id_produto    nome  preco
# 0           1  Caneca  15.99
# 1           2   Garfo   5.99
# 2           3    Faca   7.99
# 3           4  Colher   3.99
# 4           5    Copo  10.99
# Updated property [core/project].

# %%
connection = mysql.connector.connect(
    host=host,
    user=user,
    password=password,
    database=database,
)
cursor = connection.cursor()
query = 'SELECT * FROM ProdutoCategoria'
cursor.execute(query)
result = cursor.fetchall()
produtocategoria = pd.DataFrame(result,columns=cursor.column_names)
display(produtocategoria)
cursor.close()
connection.close()

from google.colab import auth
auth.authenticate_user()

project_id = "projeto-alevy"
# !gcloud config set project {project_id}

from google.cloud import storage

client = storage.Client()

bucket_name = "loja-alevy"
bucket = client.bucket(bucket_name)

produtocategoria.to_csv("loja_produtocategoria.csv", index=False)

destination_blob_name = "tabelas/loja_produtocategoria.csv"
source_file_name = "loja_produtocategoria.csv"

blob = bucket.blob(destination_blob_name)
blob.upload_from_filename(source_file_name)
# Out:
#    id_produto  id_categoria
# 0           2             1
# 1           3             1
# 2           4             1
# 3           1             2
# 4           5             2
# Updated property [core/project].
